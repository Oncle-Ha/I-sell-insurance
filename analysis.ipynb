# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as matplot
import seaborn as sns

# %%
train = pd.read_csv('data/train.csv')

# %%
train
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            0    Male   27              1.0         46.0                   1
# 1            1  Female   44              1.0         28.0                   0
# 2            2    Male   52              1.0         46.0                   0
# 3            3    Male   23              1.0         46.0                   1
# 4            4  Female   43              1.0         28.0                   0
# ...        ...     ...  ...              ...          ...                 ...
# 304883  304883  Female   20              1.0          7.0                   0
# 304884  304884  Female   24              1.0         20.0                   0
# 304885  304885  Female   25              1.0         36.0                   1
# 304886  304886    Male   22              1.0          8.0                   1
# 304887  304887  Female   26              1.0         28.0                   1
#
# ...

# %%
f, ax = plt.subplots(figsize=(15, 150))
sns.countplot(y='Policy_Sales_Channel', hue='Response', data=train).set_title('Response in different Policy Sales Channels')
# Out:
# Text(0.5,1,'Response in different Policy Sales Channels')

# %%
test = pd.read_csv('data/tmp.csv')
test
# Out:
#        Unnamed: 0     id  Gender  Age  Driving_License  Region_Code  \
# 0               0      0    Male   41              1.0          6.0
# 1               1      1  Female   28              1.0         28.0
# 2               2      2  Female   32              1.0          8.0
# 3               3      3    Male   36              1.0         28.0
# 4               4      4  Female   32              1.0         15.0
# ...           ...    ...     ...  ...              ...          ...
# 76216       76216  76216  Female   46              1.0          3.0
# 76217       76217  76217  Female   37              1.0          0.0
# 76218       76218  76218    Male   33              1.0         49.0
# 76219       76219  76219    Male   72              1.0         28.0
# 76220       76220  76220    Male   55              1.0          0.0
#
#        Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  \
# 0                       0    1-2 Year            Yes         36438.0
# ...

# %%
f, ax = plt.subplots(figsize=(15, 150))
sns.countplot(y='Policy_Sales_Channel', hue='Response', data=test).set_title('Response in different Policy Sales Channels')
# Out:
# Text(0.5,1,'Response in different Policy Sales Channels')

# %%
psc_min = np.int(np.min(train['Policy_Sales_Channel']))
psc_max = np.int(np.max(train['Policy_Sales_Channel']))
psc_counts = [ np.sum(train['Policy_Sales_Channel'] == i) for i in range(psc_min, psc_max+1)]

# %%
psc_min
# Out:
# 1

# %%
trainx = train['Gender'].copy()
trainx
# Out:
# 0           Male
# 1         Female
# 2           Male
# 3           Male
# 4         Female
#            ...
# 304883    Female
# 304884    Female
# 304885    Female
# 304886      Male
# 304887    Female
# Name: Gender, Length: 304888, dtype: object

# %%
psc_sort = psc_counts.copy()
psc_sort.sort(reverse=True)
psc_sort
# Out:
# [107465,
#  63622,
#  59009,
#  17289,
#  8496,
#  7977,
#  5382,
#  4768,
#  3102,
#  2309,
#  1494,
#  1457,
#  1268,
#  1219,
#  1118,
#  1020,
#  979,
#  960,
#  887,
#  860,
#  813,
#  737,
#  671,
#  620,
#  600,
#  581,
#  489,
#  487,
#  486,
#  475,
#  415,
#  408,
#  407,
#  405,
#  398,
#  328,
#  263,
#  251,
#  206,
#  181,
#  157,
#  143,
#  138,
#  133,
#  132,
#  131,
#  130,
#  129,
#  125,
#  108,
#  107,
#  106,
#  104,
#  103,
#  97,
#  94,
#  88,
#  87,
#  87,
#  85,
#  82,
#  80,
#  80,
#  68,
#  68,
#  66,
#  65,
#  59,
#  54,
#  54,
#  54,
#  51,
#  50,
#  49,
#  41,
#  41,
#  40,
#  39,
#  38,
#  38,
#  36,
#  30,
#  30,
#  26,
#  26,
#  26,
#  24,
#  21,
#  20,
#  20,
#  18,
#  17,
#  17,
#  17,
#  16,
#  16,
#  15,
#  15,
#  14,
#  14,
#  14,
#  13,
#  13,
#  12,
#  12,
#  11,
#  11,
#  10,
#  10,
#  10,
#  9,
#  9,
#  8,
#  8,
#  8,
#  7,
#  7,
#  6,
#  5,
#  5,
#  5,
#  5,
#  5,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
# ...

# %%
psc_threshold = psc_sort[7]
psc_threshold
# Out:
# 4768

# %%
train['Policy_Sales_Channel']
# Out:
# 0         152.0
# 1          26.0
# 2         124.0
# 3         152.0
# 4         124.0
#           ...
# 304883    160.0
# 304884     26.0
# 304885    152.0
# 304886    152.0
# 304887    152.0
# Name: Policy_Sales_Channel, Length: 304888, dtype: float64

# %%
f, ax = plt.subplots(figsize=(15, 150))
sns.countplot(y='Region_Code', hue='Response', data=train).set_title('Response in different Policy Sales Channels')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-b1cdf06a99e4> in <module>()
# ----> 1 train['Policy_Sales_Channel'].astype(int)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
#     597     def convert(
#
# ...
